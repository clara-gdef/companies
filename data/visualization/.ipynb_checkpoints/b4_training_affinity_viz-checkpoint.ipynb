# %%
import pickle as pkl
import yaml
import numpy as np
import matplotlib.pyplot as plt
import os
from sklearn.preprocessing import normalize

# %%
global CFG
with open("../../config.yaml", "r") as ymlfile:
    CFG = yaml.load(ymlfile, Loader=yaml.SafeLoader)

# %%
rep_type = "ft"

# %%
xp_title = "disc_poly_b4_training_" + rep_type + "_avg_b4Training_1_1e-06"

# %%
xp_title
disc_poly_b4_training_ft_avg_b4Training_1_1e-06
# Out:
#   File "<ipython-input-46-563d7740afe8>", line 2
#     disc_poly_b4_training_ft_avg_b4Training_1_1e-06
#                                                   ^
# SyntaxError: invalid token

# %%
res_path = os.path.join(CFG["datadir"], "OUTPUTS_well_classified_" + xp_title)
with open(res_path, "rb") as f:
    b4_training = pkl.load(f)

# %%
b4_training["cie"].keys()
# Out:
# dict_keys([846743, 816326, 731356, 448170, 433780, 13352, 760174, 71371, 627185, 300964, 762510, 551992, 105169, 18098, 237469, 30173, 409723, 198835, 513306, 705476, 313233, 149685, 761660, 596816, 746166, 736518, 405897, 178186, 806409, 777996, 91791, 147345, 234513, 512295, 141879, 407865, 398395, 272187, 608959, 776137, 538315, 309452, 461006, 747472, 411753, 841194, 90475, 269544, 693832, 615624, 482003, 559123, 774869, 205539, 282500, 752567, 652035, 702610, 151965, 76344, 803832, 463451, 558340, 278426, 39120, 794507, 206210, 67108, 337636, 462631, 756842, 705195, 518062, 471251, 30138, 465186, 2514, 816915, 549564, 710407, 560298, 657463, 725214, 702502, 356559, 177203, 83190, 842878, 145567, 772963, 318486, 573376, 690350, 330256, 407953, 725877, 686236, 804671, 474192, 591733, 128579, 39816, 234769, 167966, 70052, 801337, 845892, 96839, 676686, 404950, 493278, 322790, 363752, 701547, 526580, 439288, 592636, 281968, 4816, 133810, 429687, 594143, 760902, 836309, 233591, 779313, 179904, 447940, 702810, 421350, 588126, 191373, 653883, 766851, 496912, 816158, 59550, 9374, 116898, 87586, 267433, 618287, 755121, 527154, 174775, 360276, 434774, 251607, 818902, 424671, 435936, 150760, 420457, 208753, 507380, 696055, 22181, 62660, 843663, 375791, 514340, 765874, 59831, 510923, 155469, 722009, 386659, 154982, 202775, 716827, 828959, 674878, 778823, 827988, 393304, 81504, 629875, 270459, 684668, 284310, 589463, 314012, 165539, 578212, 825514, 441017, 162510, 249042, 189143, 486102, 757978, 758500, 340199, 310013, 169214, 282379, 343824, 732436, 104744, 789296, 354630, 813391, 784212, 677208, 653680, 177522, 597876, 99728, 381848, 42403, 217509, 636328, 450475, 45483, 764333, 739268, 473541, 762828, 221132, 163282, 162259, 666071, 780257, 538086, 807411, 737781, 768503, 717158, 663389, 825435, 229452, 4353, 154734, 531990, 791094, 452091, 602129, 725139, 652386, 424809, 825965, 467702, 450048, 9123, 141990, 828551, 284838, 518219, 669486, 518959, 563631, 422004, 404794, 79745, 779098, 432206, 520622, 604977, 237018, 362783, 764791, 447328, 774985, 381825, 779206, 353696, 433041, 115121, 259377, 760022, 239321, 821821, 604877, 12019, 645368, 584760, 116502, 134691, 220197, 616238, 494767, 137799, 833743, 1873, 825426, 660311, 581979, 568675, 840431, 73471, 691064, 799999, 500803, 470086, 419529, 698197, 93390, 33218, 346580, 567360, 281316, 332681, 458941, 727708, 411359, 844547, 4449, 819394, 208584, 262738, 505683, 803956, 694519, 419389, 222559, 273800, 344544, 696293, 605096, 222224, 175583, 838731, 548841, 97050, 719876, 112522, 51732, 615899, 539451, 703548, 395521, 557187, 238852, 121738, 233483, 309644, 636429, 494221, 122772, 700822, 144281, 706074, 476443, 382374, 246698, 21419, 436398, 30387, 785978, 608315, 799038, 465855, 241349, 248261, 235847, 217415, 7241, 309450, 748749, 848717, 577359, 511957, 797269, 348636, 311645, 801756, 396260, 489191, 47209, 337132, 631149, 792815, 94704, 587129, 576982, 151869, 298590, 195332, 841384, 354257, 611456, 679350, 559684, 833382, 241495, 567682, 747270, 186890, 352141, 702348, 240917, 41624, 348184, 301594, 562073, 471581, 749348, 502565, 166437, 76327, 83883, 269230, 666929, 803251, 89396, 19644, 283967, 504382, 653375, 748236, 344272, 479313, 606033, 129744, 372949, 365015, 453208, 794588, 629218, 777187, 272487, 252777, 304746, 471019, 786033, 403057, 247539, 274682, 769864, 211485, 334177, 300974, 764545, 438827, 72688, 195831, 75981, 670419, 563937, 727778, 165411, 348781, 199610, 582587, 280189, 580375, 160740, 351857, 396948, 288161, 731594, 722933, 842587, 138001, 638237, 760740, 584214, 313772, 441303, 392089, 521241, 468132, 402601, 294705, 472117, 477378, 39246, 789466, 406645, 810493, 128808, 87913, 454798, 637218, 55846, 794157, 139183, 796209, 461754, 66017, 480119, 6780, 102009, 678996, 807783, 503831, 775063, 375033, 360773, 716117, 281853, 32741, 202184, 252873, 336107, 607885, 167870, 595062, 826105, 252956, 433470, 422685, 127595, 197314, 317541, 501863, 72618 ...

# %%
cie_dict = [i for i in b4_training["cie"]]
cie_outputs = np.array([b4_training["cie"][i][0] for i in cie_dict])
clus_dict = [i for i in b4_training["clus"]]
clus_outputs = np.array([b4_training["clus"][i][0] for i in clus_dict])
dpt_dict = [i for i in b4_training["dpt"]]
dpt_outputs = np.array([b4_training["dpt"][i][0] for i in dpt_dict])

# %%
b4_training["dpt"]
# Out:
# {127475: (array([24.514856, 24.090443, 23.943928, ..., 24.047323, 25.08767 ,
#          23.411324], dtype=float32), 588),
#  13658: (array([25.003208, 22.00551 , 22.42345 , ..., 23.171469, 25.287569,
#          22.04536 ], dtype=float32), 1450),
#  749642: (array([29.273018, 24.706589, 25.80358 , ..., 25.107977, 26.743868,
#          24.877213], dtype=float32), 1637),
#  408205: (array([25.283657, 23.462744, 23.88285 , ..., 23.293692, 23.415258,
#          23.674135], dtype=float32), 1637),
#  84174: (array([26.663963, 24.054176, 24.550577, ..., 23.956451, 24.179882,
#          24.286575], dtype=float32), 1637),
#  617170: (array([26.036879, 23.969421, 24.13932 , ..., 24.125227, 24.108059,
#          24.421179], dtype=float32), 1637),
#  271670: (array([25.208633, 23.341713, 23.592712, ..., 23.499725, 23.63495 ,
#          23.679874], dtype=float32), 1637),
#  226588: (array([26.163204, 23.682564, 24.909485, ..., 22.905039, 24.621851,
#          26.76153 ], dtype=float32), 3078),
#  318224: (array([27.656565, 25.82263 , 26.044575, ..., 24.200808, 23.350613,
#          24.555283], dtype=float32), 4374),
#  66480: (array([28.728693, 25.295502, 25.276932, ..., 24.782902, 24.2361  ,
#          25.114319], dtype=float32), 4567),
#  221792: (array([25.409313, 25.023966, 24.27057 , ..., 24.298962, 23.04918 ,
#          23.970942], dtype=float32), 4635)}

# %%
fig, ax = plt.subplots(1, 3, figsize=(20, 20))
ax[0].matshow(normalize(cie_outputs))
ax[1].matshow(normalize(clus_outputs))
cax = ax[2].matshow(normalize(dpt_outputs))

ax.set_title("cie_outputs")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-a539cd38125d> in <module>
#       4 cax = ax[2].matshow(normalize(dpt_outputs))
#       5
# ----> 6 ax.set_title("cie_outputs")
#       7 plt.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'set_title'
